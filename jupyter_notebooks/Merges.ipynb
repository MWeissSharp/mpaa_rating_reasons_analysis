# %%
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# Read in TMDB data

# %%
tmdb = pd.read_pickle('../data/tmdb_results.pkl')
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28952 entries, 0 to 28951
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          28952 non-null  float64
#  1   imdb_id                     24983 non-null  object
#  2   title                       28952 non-null  object
#  3   original_title              28952 non-null  object
#  4   release_date                28951 non-null  datetime64[ns]
#  5   budget                      28952 non-null  float64
#  6   revenue                     28952 non-null  float64
#  7   popularity                  28952 non-null  float64
#  8   vote_average                28952 non-null  float64
#  9   vote_count                  28952 non-null  float64
#  10  release_dates.results       28952 non-null  object
#  11  genres                      28952 non-null  object
#  12  original_language           28952 non-null  object
#  13  overview                    28952 non-null  object
#  14  production_companies        28952 non-null  object
#  15  production_countries        28952 non-null  object
#  16  runtime                     28952 non-null  float64
#  17  spoken_languages            28952 non-null  object
#  18  status                      28952 non-null  object
#  19  tagline                     28952 non-null  object
#  20  video                       28952 non-null  object
#  21  belongs_to_collection.id    1610 non-null   float64
#  22  belongs_to_collection.name  1610 non-null   object
#  23  release_year                28951 non-null  float64
# dtypes: datetime64[ns](1), float64(9), object(14)
# memory usage: 5.3+ MB

# %%
# Pull out only the US certification data
tmdb_certs = []

for n in range(0, len(tmdb)):
    us_dicts = [d for d in tmdb['release_dates.results'][n] if d['iso_3166_1'] == 'US']
    tmdb_certs.append(us_dicts)
    
tmdb['certifications'] = tmdb_certs

# %%
#Drop rows with no US data
tmdb_us = tmdb.loc[tmdb['certifications'].astype(bool)].reset_index(drop=True)

# %%
# Drill down to the relevant mpaa data
tmdb_mpaa = []

for n in range(0, len(tmdb_us)):
    if [d for d in tmdb_us['certifications'][n][0]['release_dates'] if d['certification'] != '']:
        cert_info = [d for d in tmdb_us['certifications'][n][0]['release_dates'] if d['certification'] != '']
    else:
        cert_info = [{'certification' : 'None'}]
    tmdb_mpaa.append(cert_info)

# %%
tmdb_us['mpaa'] = pd.json_normalize(pd.json_normalize(tmdb_mpaa).iloc[:,0])['certification']

# %%
tmdb_us['mpaa'].value_counts()
# Out:
# None       8648
# R          6270
# PG-13      2634
# PG         1270
# NR          714
# G           370
# NC-17        40
# UR            1
# PG-13         1
# Unrated       1
# Name: mpaa, dtype: int64

# %%
tmdb_us = tmdb_us.drop(columns = ['release_dates.results', 'status', 'belongs_to_collection.id', 'belongs_to_collection.name', 'tagline', 'certifications'])

# %% [markdown]
# Take a look at the financial data

# %%
tmdb_us[['budget', 'revenue']].describe()
# Out:
#              budget       revenue
# count  1.994900e+04  1.994900e+04
# mean   7.622580e+06  2.028765e+07
# std    2.393799e+07  9.475590e+07
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    3.000000e+05  9.692000e+03
# max    3.560000e+08  2.923706e+09

# %%
# Get rows that have a minimum of a $1000 budget and $10000 in revenue
tmdb_fin = tmdb_us.loc[(tmdb_us['budget'] > 1000) & (tmdb_us['revenue'] > 10000)].reset_index(drop=True)
tmdb_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3841 entries, 0 to 3840
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3841 non-null   float64
#  1   imdb_id               3838 non-null   object
#  2   title                 3841 non-null   object
#  3   original_title        3841 non-null   object
#  4   release_date          3841 non-null   datetime64[ns]
#  5   budget                3841 non-null   float64
#  6   revenue               3841 non-null   float64
#  7   popularity            3841 non-null   float64
#  8   vote_average          3841 non-null   float64
#  9   vote_count            3841 non-null   float64
#  10  genres                3841 non-null   object
#  11  original_language     3841 non-null   object
#  12  overview              3841 non-null   object
#  13  production_companies  3841 non-null   object
#  14  production_countries  3841 non-null   object
#  15  runtime               3841 non-null   float64
#  16  spoken_languages      3841 non-null   object
#  17  video                 3841 non-null   object
#  18  release_year          3841 non-null   float64
#  19  mpaa                  3841 non-null   object
# dtypes: datetime64[ns](1), float64(8), object(11)
# memory usage: 600.3+ KB

# %%
tmdb_fin[['budget', 'revenue']].describe()
# Out:
#              budget       revenue
# count  3.841000e+03  3.841000e+03
# mean   3.685269e+07  1.029922e+08
# std    4.262726e+07  1.948610e+08
# min    6.000000e+03  1.030000e+04
# 25%    9.804690e+06  8.112712e+06
# 50%    2.200000e+07  3.461970e+07
# 75%    4.990000e+07  1.142811e+08
# max    3.560000e+08  2.923706e+09

# %%
# Check for duplicate movie names in the same year financial data, there are none in this dataset
tmdb_fin.loc[tmdb_fin.duplicated(subset=['title', 'release_year'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, imdb_id, title, original_title, release_date, budget, revenue, popularity, vote_average, vote_count, genres, original_language, overview, production_companies, production_countries, runtime, spoken_languages, video, release_year, mpaa]
# Index: []

# %%
# Create a budget to revenue multiplier value
tmdb_fin['budge:rev'] = tmdb_fin['revenue'] / tmdb_fin['budget']

tmdb_fin.head()
# Out:
#         id    imdb_id                       title              original_title  \
# 0    812.0  tt0103639                     Aladdin                     Aladdin
# 1  10437.0  tt0104940  The Muppet Christmas Carol  The Muppet Christmas Carol
# 2  16314.0  tt0103596                    3 Ninjas                    3 Ninjas
# 3  10406.0  tt0104187                  Encino Man                  Encino Man
# 4    137.0  tt0107048               Groundhog Day               Groundhog Day
#
#   release_date      budget      revenue  popularity  vote_average  vote_count  \
# 0   1992-11-25  28000000.0  504050219.0      52.485         7.645     10297.0
# 1   1992-12-10  12000000.0   27281507.0       8.653         7.367       797.0
# 2   1992-08-07   6500000.0   29000301.0      11.402         5.701       384.0
# 3   1992-05-22   7000000.0   40693477.0       9.375         5.799       566.0
# 4   1993-02-11  14600000.0   71074049.0      26.404         7.603      6984.0
#
#    ... original_language                                           overview  \
# 0  ...                en  Disney’s animated take on the classic Arabian ...
# 1  ...                en  A retelling of the classic Dickens tale of Ebe...
# 2  ...                en  Each year, three brothers Samuel, Jeffrey and ...
# 3  ...                en  High school misfits Stoney and Dave discover a...
# 4  ...                en  A narcissistic TV weatherman, along with his a...
#
#                                 production_companies  \
# 0  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 1  [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 2  [{'id': 9195, 'logo_path': '/ou5BUbtulr6tIt699...
# 3  [{'id': 915, 'logo_path': '/4neXXpjSJDZPBGBnfW...
# 4  [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLu...
#
#                                 production_countries runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...    95.0
# 1  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...    85.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...    84.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...    88.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...   101.0
#
#                                     spoken_languages  video release_year  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  False       1992.0
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  False       1992.0
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  False       1992.0
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  False       1992.0
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  False       1993.0
#
#    mpaa  budge:rev
# 0     G  18.001794
# 1     G   2.273459
# 2    PG   4.461585
# 3    PG   5.813354
# 4    PG   4.868086
#
# [5 rows x 21 columns]

# %% [markdown]
# Take a look at the popularity/watcher rating data

# %%
tmdb_us[['vote_count', 'vote_average', 'popularity']].describe()
# Out:
#          vote_count  vote_average    popularity
# count  19949.000000  19949.000000  19949.000000
# mean     528.690862      4.558984      8.272913
# std     1831.619479      2.667507     72.108074
# min        0.000000      0.000000      0.600000
# 25%        1.000000      3.000000      0.679000
# 50%       15.000000      5.500000      2.789000
# 75%      191.000000      6.445000      8.944000
# max    33697.000000     10.000000   8687.747000

# %%
tmdb_us.loc[(tmdb_us['vote_count'] > 0)]['vote_count'].describe()
# Out:
# count    15901.000000
# mean       663.282435
# std       2029.695108
# min          1.000000
# 25%          6.000000
# 50%         40.000000
# 75%        331.000000
# max      33697.000000
# Name: vote_count, dtype: float64

# %%
# Filter to rows that have at least 40 votes
tmdb_pop = tmdb_us.loc[(tmdb_us['vote_count'] >= 40)].reset_index(drop=True)
tmdb_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7999 non-null   float64
#  1   imdb_id               7999 non-null   object
#  2   title                 7999 non-null   object
#  3   original_title        7999 non-null   object
#  4   release_date          7999 non-null   datetime64[ns]
#  5   budget                7999 non-null   float64
#  6   revenue               7999 non-null   float64
#  7   popularity            7999 non-null   float64
#  8   vote_average          7999 non-null   float64
#  9   vote_count            7999 non-null   float64
#  10  genres                7999 non-null   object
#  11  original_language     7999 non-null   object
#  12  overview              7999 non-null   object
#  13  production_companies  7999 non-null   object
#  14  production_countries  7999 non-null   object
#  15  runtime               7999 non-null   float64
#  16  spoken_languages      7999 non-null   object
#  17  video                 7999 non-null   object
#  18  release_year          7999 non-null   float64
#  19  mpaa                  7999 non-null   object
# dtypes: datetime64[ns](1), float64(8), object(11)
# memory usage: 1.2+ MB

# %%
tmdb_pop[['vote_count', 'vote_average', 'popularity']].describe()
# Out:
#          vote_count  vote_average   popularity
# count   7999.000000   7999.000000  7999.000000
# mean    1308.712089      6.249899    17.937572
# std     2711.346533      0.859618   112.975531
# min       40.000000      1.860000     0.600000
# 25%      112.000000      5.708000     7.281500
# 50%      326.000000      6.277000    10.423000
# 75%     1183.500000      6.844000    16.343500
# max    33697.000000      8.702000  8687.747000

# %%
# check for duplicates in the popularity data, there are 8 movies that appear twice
tmdb_pop.loc[tmdb_pop.duplicated(subset=['title', 'release_year'], keep=False)].sort_values('title')#['mpaa'].value_counts()
# Out:
#             id     imdb_id      title original_title release_date      budget  \
# 0        812.0   tt0103639    Aladdin        Aladdin   1992-11-25  28000000.0
# 7707  343693.0   tt0827990    Aladdin        Aladdin   1992-04-27         0.0
# 1907  509635.0   tt7711170      Alone          Alone   2020-09-10         0.0
# 7333  661950.0  tt10192566      Alone          Alone   2020-10-16         0.0
# 6536  526052.0   tt2573372   Becoming       Becoming   2020-04-16         0.0
# 7684  699280.0  tt12221748   Becoming       Becoming   2020-05-06         0.0
# 3146  257874.0   tt2991296    Beneath        Beneath   2013-10-08        89.0
# 7459  191619.0   tt2325518    Beneath        Beneath   2013-07-19         0.0
# 5363  340601.0   tt2069797   Delirium       Delirium   2018-05-10         0.0
# 7612  401732.0   tt3131050   Delirium       Delirium   2018-01-19   1000000.0
# 7172  360339.0   tt3032282       Eden           Eden   2014-11-19   2300000.0
# 7714  283330.0   tt3090634       Eden           Eden   2014-11-19         0.0
# 3601   25195.0   tt1216492  Leap Year      Leap Year   2010-01-08  19000000.0
# 7485   63555.0   tt1537401  Leap Year   Año bisiesto   2010-05-17         0.0
# 6090  472553.0   tt3688342        Zoo            Zoo   2018-06-08   4000000.0
# 7842  552504.0   tt7624934        Zoo            Zoo   2018-10-05         0.0
#
#           revenue  popularity  vote_average  vote_count  \
# 0     504050219.0      52.485         7.645     10297.0
# 7707          0.0       4.454         6.100        60.0
# 1907          0.0      24.161         6.290       538.0
# 7333          0.0      11.253         5.895       147.0
# 6536          0.0      10.025         5.500        54.0
# 7684          0.0       6.297         7.500       135.0
# 3146          0.0       8.740         5.397       136.0
# 7459          0.0       7.122         3.677       110.0
# 5363          0.0       8.039         5.753       215.0
# 7612          0.0       6.358         4.800        41.0
# 7172          0.0       5.554         5.274        53.0
# 7714      65460.0       6.997         5.856       112.0
# 3601   32686500.0      25.270         6.883      1848.0
# 7485          0.0       6.295         6.400       226.0
# 6090     231719.0       8.329         6.700        91.0
# 7842          0.0       5.454         6.200        96.0
#
#                                                  genres original_language  \
# 0     [{'id': 16, 'name': 'Animation'}, {'id': 10751...                en
# 7707  [{'id': 16, 'name': 'Animation'}, {'id': 14, '...                en
# 1907  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...                en
# 7333  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...                en
# 6536  [{'id': 878, 'name': 'Science Fiction'}, {'id'...                en
# 7684                [{'id': 99, 'name': 'Documentary'}]                en
# 3146                     [{'id': 27, 'name': 'Horror'}]                en
# 7459                     [{'id': 27, 'name': 'Horror'}]                en
# 5363  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...                en
# 7612  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...                en
# 7172  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...                en
# 7714  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...                en
# 3601  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...                en
# 7485  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...                es
# 6090  [{'id': 10751, 'name': 'Family'}, {'id': 10752...                en
# 7842  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...                en
#
#                                                overview  \
# 0     Disney’s animated take on the classic Arabian ...
# 7707  A young man's life is turned around with the h...
# 1907  A recently widowed traveler is kidnapped by a ...
# 7333  When an outbreak hits, Aidan barricades himsel...
# 6536  A couple on a road trip through America encoun...
# 7684  Join former first lady Michelle Obama in an in...
# 3146  A crew of coal miners becomes trapped 600 feet...
# 7459  Six high school seniors celebrating with day's...
# 5363  A man recently released from a mental institut...
# 7612  A group of young men dare a classmate to reach...
# 7172  After their plane crashes off the coast of a d...
# 7714  Paul, a teenager in the underground scene of e...
# 3601  When yet another anniversary passes without a ...
# 7485  Journalist Laura works at home, isolating hers...
# 6090  Young Tom and his misfit friends fight to save...
# 7842  A couple trying to save their marriage during ...
#
#                                    production_companies  \
# 0     [{'id': 2, 'logo_path': '/wdrCwmRnLFJhEoH8GSfy...
# 7707  [{'id': 10820, 'logo_path': None, 'name': 'Ame...
# 1907  [{'id': 111865, 'logo_path': '/4UtwPhdPtJX519T...
# 7333  [{'id': 141537, 'logo_path': None, 'name': 'JA...
# 6536  [{'id': 44632, 'logo_path': '/neCKH4sJCBhZ1B4Q...
# 7684  [{'id': 122147, 'logo_path': '/eotra9uY7zyivEz...
# 3146  [{'id': 24428, 'logo_path': '/zH6o8LH5x3mpaJgs...
# 7459  [{'id': 12671, 'logo_path': None, 'name': 'Chi...
# 5363  [{'id': 562, 'logo_path': '/azANEzu3H3Kztzt63s...
# 7612  [{'id': 3312, 'logo_path': None, 'name': 'Mart...
# 7172  [{'id': 23513, 'logo_path': None, 'name': 'Omb...
# 7714  [{'id': 32288, 'logo_path': None, 'name': 'Ad ...
# 3601  [{'id': 58262, 'logo_path': None, 'name': 'Bir...
# 7485                                                 []
# 6090  [{'id': 17821, 'logo_path': '/bZp3beVId2zVhxrx...
# 7842  [{'id': 16820, 'logo_path': None, 'name': 'Pin...
#
#                                    production_countries  runtime  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...     95.0
# 7707  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...     49.0
# 1907  [{'iso_3166_1': 'US', 'name': 'United States o...     98.0
# 7333  [{'iso_3166_1': 'US', 'name': 'United States o...     92.0
# 6536  [{'iso_3166_1': 'US', 'name': 'United States o...     98.0
# 7684  [{'iso_3166_1': 'US', 'name': 'United States o...     89.0
# 3146  [{'iso_3166_1': 'US', 'name': 'United States o...     89.0
# 7459  [{'iso_3166_1': 'US', 'name': 'United States o...     90.0
# 5363  [{'iso_3166_1': 'US', 'name': 'United States o...     96.0
# 7612  [{'iso_3166_1': 'US', 'name': 'United States o...     86.0
# 7172  [{'iso_3166_1': 'MY', 'name': 'Malaysia'}, {'i...     97.0
# 7714           [{'iso_3166_1': 'FR', 'name': 'France'}]    131.0
# 3601  [{'iso_3166_1': 'IE', 'name': 'Ireland'}, {'is...    100.0
# 7485           [{'iso_3166_1': 'MX', 'name': 'Mexico'}]     94.0
# 6090  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...     96.0
# 7842  [{'iso_3166_1': 'DK', 'name': 'Denmark'}, {'is...     95.0
#
#                                        spoken_languages  video  release_year  \
# 0     [{'english_name': 'English', 'iso_639_1': 'en'...  False        1992.0
# 7707  [{'english_name': 'English', 'iso_639_1': 'en'...  False        1992.0
# 1907  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2020.0
# 7333  [{'english_name': 'German', 'iso_639_1': 'de',...  False        2020.0
# 6536  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2020.0
# 7684  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2020.0
# 3146  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2013.0
# 7459  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2013.0
# 5363  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2018.0
# 7612  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2018.0
# 7172  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2014.0
# 7714  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2014.0
# 3601  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2010.0
# 7485  [{'english_name': 'German', 'iso_639_1': 'de',...  False        2010.0
# 6090  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2018.0
# 7842  [{'english_name': 'English', 'iso_639_1': 'en'...  False        2018.0
#
#       mpaa
# 0        G
# 7707  None
# 1907     R
# 7333     R
# 6536  None
# 7684    PG
# 3146    NR
# 7459  None
# 5363     R
# 7612  None
# 7172     R
# 7714     R
# 3601    PG
# 7485  None
# 6090    PG
# 7842  None

# %%
tmdb.loc[(tmdb['title'] == 'Alone') 
         & 
         (tmdb['release_year'] == 2020) 
         & 
         (tmdb['certifications'].astype(bool))]['certifications'].reset_index(drop=True)[0]

# %% [markdown]
# Read in MPAA data

# %%
mpaa = pd.read_csv('../data/clean_mpaa_data.csv').drop(columns = 'Unnamed: 0')
mpaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21685 entries, 0 to 21684
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        21685 non-null  object
#  1   rating       21685 non-null  object
#  2   reason       20862 non-null  object
#  3   distributor  21672 non-null  object
#  4   alt_titles   6222 non-null   object
#  5   other        1308 non-null   object
#  6   year         21685 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.2+ MB

# %%
mpaa['year'].value_counts().sort_index()
# Out:
# 1992    606
# 1993    602
# 1994    617
# 1995    692
# 1996    693
# 1997    658
# 1998    661
# 1999    679
# 2000    756
# 2001    735
# 2002    782
# 2003    937
# 2004    857
# 2005    926
# 2006    849
# 2007    848
# 2008    902
# 2009    789
# 2010    701
# 2011    751
# 2012    732
# 2013    709
# 2014    709
# 2015    614
# 2016    608
# 2017    571
# 2018    578
# 2019    512
# 2020    509
# 2021    521
# 2022    581
# Name: year, dtype: int64

# %%
# Adjust title formats to align with TMDB format
mpaa['the_fix'] = mpaa['title'].str.endswith(', The')
mpaa['a_fix'] = mpaa['title'].str.endswith(', A')
mpaa['tmdb_title'] = mpaa['title'].str.replace(', The', '').str.replace(', A', '')
mpaa.loc[mpaa['the_fix'] == True, 'tmdb_title'] = 'The ' + mpaa['tmdb_title']
mpaa.loc[mpaa['a_fix'] == True, 'tmdb_title'] = 'A ' + mpaa['tmdb_title']
mpaa['tmdb_title'] = mpaa['tmdb_title'].fillna(mpaa['title'])
mpaa = mpaa.drop(columns = ['the_fix', 'a_fix'])

# %%
mpaa = mpaa.rename(columns = {'year' : 'mpaa_year'})

# %%
mpaa['mpaa_year-1'] = mpaa['mpaa_year'] - 1

mpaa['mpaa_year+1'] = mpaa['mpaa_year'] + 1

mpaa['mpaa_year+2'] = mpaa['mpaa_year'] + 2

# %%
ratings = ['G', 'PG', 'PG-13', 'R', 'NC-17']

tmdb_w_rating = tmdb_us.loc[tmdb_us['mpaa'].isin(ratings)]
tmdb_w_rating

# %%
mpaa.loc[(mpaa['distributor'].fillna('None').str.contains('Home Video'))
        ]

# %%
mpaa.loc[mpaa.duplicated(subset=['tmdb_title', 'mpaa_year', 'rating'], keep=False)]

# %%
tmdb_us.loc[tmdb_us.duplicated(subset=['title', 'release_year', 'mpaa'], keep=False)].sort_values('title')

# %%
merge1 = pd.merge(mpaa, tmdb_us, left_on = ['tmdb_title', 'mpaa_year-1',], right_on = ['title', 'release_year'])
len(merge1)

# %%
merge2 = pd.merge(mpaa, tmdb_us, left_on = ['tmdb_title', 'mpaa_year+1'], right_on = ['title', 'release_year'])
len(merge2)

# %%
merge3 = pd.merge(mpaa, tmdb_us, left_on = ['tmdb_title', 'mpaa_year+2'], right_on = ['title', 'release_year'])

# %%
pd.concat([merge1, merge2, merge3])

# %%
pd.merge(mpaa, tmdb_us, left_on = ['tmdb_title'], right_on = ['title'])

# %%
tmdb_us['mpaa'].value_counts()

# %%
pd.merge(mpaa, tmdb_w_rating, left_on = ['tmdb_title', 'rating'], right_on = ['title', 'mpaa'], how = 'inner')

# %%
num = pd.read_pickle('../data/numbers_data.pkl').drop(columns = 'Unnamed: 0')
num.columns = ['release_date', 'title', 'budget_num', 'domestic_gross_num', 'worldwide_gross_num']
num['release_date'] = pd.to_datetime(num['release_date'].str.replace('Unknown', ''))
num['release_year'] = num['release_date'].dt.year
num.info()

# %%
num = num.loc[(num['release_year'] >=1992)
        &
        (num['release_year'] <= 2022)].reset_index(drop=True)

# %%
num.info()
