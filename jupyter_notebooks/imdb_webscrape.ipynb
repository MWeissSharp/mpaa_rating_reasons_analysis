# %%
import requests
from bs4 import BeautifulSoup as BS

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.select import Select

import time

import pandas as pd
import numpy as np

# %%
'https://www.imdb.com/search/title/?title_type=feature,tv_movie,documentary,short,video&release_date=1992-01-01,1992-12-31&certificates=US%3AG,US%3APG,US%3APG-13,US%3AR,US%3ANC-17&adult=include&count=250'

# %%
URL = 'https://www.imdb.com/search/title/?title_type=feature,tv_movie,documentary,short,video&release_date=1992-01-01,1992-12-31&certificates=US%3AG,US%3APG,US%3APG-13,US%3AR,US%3ANC-17&adult=include&count=250'
response = requests.get(URL)
response
# Out:
# <Response [200]>

# %%
soup = BS(response.text)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Feature Film/TV Movie/Documentary/Short Film/Video,
# Released between 1992-01-01 and 1992-12-31,
# US-G/US-PG/US-PG-13/US-R/US-NC-17,
# Including Adult Titles
# (Sorted by Popularity Ascending) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
# ...

# %%
soup.find('div', attrs = {'class' : 'desc'})
# Out:
# <div class="desc">
# <span>1-250 of 590 titles.</span>
# <span class="ghost">|</span> <a class="lister-page-next next-page" href="/search/title/?title_type=feature,tv_movie,documentary,short,video&amp;release_date=1992-01-01,1992-12-31&amp;certificates=US%3AG,US%3APG,US%3APG-13,US%3AR,US%3ANC-17&amp;adult=include&amp;count=250&amp;start=251">Next »</a>
# </div>

# %%
def scrape_page(start_yr, end_yr):
    
    driver.get(f'https://www.imdb.com/search/title/?title_type=feature,tv_movie,documentary,short,video&release_date={start_yr}-01-01,{end_yr}-12-31&certificates=US%3AG,US%3APG,US%3APG-13,US%3AR,US%3ANC-17&adult=include&sort=alpha,asc&count=250&ref_=adv_prv')

# %%
ids = [x.get('data-tconst') for x in soup.find_all('div', attrs={'class' : 'ribbonize'})]

# %%
len(ids)
# Out:
# 250

# %%
title = [x.find('a').text for x in soup.find_all('h3', attrs={'class' : 'lister-item-header'})]

# %%
len(title)
# Out:
# 250

# %%
soup.find_all('span', attrs = {'class' : 'certificate'})[0].text
# Out:
# 'R'

# %%
mpaa = [x.text for x in soup.find_all('span', attrs = {'class' : 'certificate'})]

# %%
len(mpaa)
# Out:
# 250

# %%
lengths = mpaa = [x.text for x in soup.find_all('span', attrs = {'class' : 'runtime'})]

# %%
len(lengths)
# Out:
# 250

# %%
genres = [x.text.strip() for x in soup.find_all('span', attrs = {'class' : 'genre'})]

# %%
len(genres)
# Out:
# 250

# %%
years = [x.text for x in soup.find_all('span', attrs={'class' : 'lister-item-year text-muted unbold'})]

# %%
len(years)
# Out:
# 250

# %%
imdb_ratings = [x.text.strip() for x in soup.find_all('div', attrs={'class' : 'inline-block ratings-imdb-rating'})]

# %%
metascores = []

for i in range (0, 250):
    if soup.find_all('div', attrs = {'class' : 'ratings-bar'})[i].find('div', attrs = {'class' : 'inline-block ratings-metascore'}):
        meta = (
            soup.find_all('div', attrs = {'class' : 'ratings-bar'})[i]
            .find('div', attrs = {'class' : 'inline-block ratings-metascore'})
            .find('span').text.strip()
        )
    else:
        meta = ''
    metascores.append(meta)

# %%
len(metascores)
# Out:
# 250

# %%
votes_and = [x.text for x in soup.find_all('p', attrs = {'class' : 'sort-num_votes-visible'})]

# %%
len(votes_and)
# Out:
# 250

# %%
soup.find_all('h3', attrs={'class' : 'lister-item-header'})[0].get
# Out:
# <h3 class="lister-item-header">
# <span class="lister-item-index unbold text-primary">1.</span>
# <a href="/title/tt0105812/">White Men Can't Jump</a>
# <span class="lister-item-year text-muted unbold">(1992)</span>
# </h3>

# %%
URL2 = 'https://www.imdb.com/title/tt0104694/parentalguide?ref_=tt_stry_pg'
response2 = requests.get(URL2)
response2
# Out:
# <Response [200]>

# %%
soup2 = BS(response2.text)
soup2
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>A League of Their Own (1992) - Parents Guide - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/title/tt0104694/parentalguide" rel="canonical"/>
# ...

# %%
soup2.find('tr', attrs = {'id': "mpaa-rating"}).find_all('td')[1].text
# Out:
# 'Rated PG for language'

# %%
URL3 = 'https://www.imdb.com/title/tt0104694/?ref_=tt_pg'
response3 = requests.get(URL3)
response3
# Out:
# <Response [403]>
